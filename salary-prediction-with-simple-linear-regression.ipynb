# %% [markdown]
# <a href="https://www.kaggle.com/code/neerajkld/salary-prediction-with-simple-linear-regression?scriptVersionId=150840294" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# # <span style="color:purple;"> **Salary Prediction**

# %% [markdown]
# ![image.png](attachment:f4d01179-5427-459f-aff7-8a30a44aacc3.png)

# %% [markdown]
# ### <span style="color:purple;"> **Scenario**
#
# #### <span style="color:dark black;">**To build a machine learning model and predict the salary of the employees based on year of experience.**

# %% [markdown]
# ### <span style="color:purple;">**Dataset Summary**
#
# #### **This dataset is randomly created to show you how we can use machine learning technique and build a Linear Regression model to predict the salary of an employee based on years of experience.**
#
# * **This dataset consists of two columns**
# * **Salary- Represent the salary of a person**
# * **Years- Years of experience**
# * **Note: - It's a small dataset which is being used for only demo purpose**

# %%
# step 1. import library
import pandas as pd

# %%
# step 2. import data
df = pd.read_csv('https://github.com/YBI-Foundation/Dataset/raw/main/Salary%20Data.csv')

# %%
df.head()
# Out:
#    Experience Years  Salary
# 0               1.1   39343
# 1               1.2   42774
# 2               1.3   46205
# 3               1.5   37731
# 4               2.0   43525

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 40 entries, 0 to 39
# Data columns (total 2 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Experience Years  40 non-null     float64
#  1   Salary            40 non-null     int64
# dtypes: float64(1), int64(1)
# memory usage: 768.0 bytes

# %%
df.describe()
# Out:
#        Experience Years         Salary
# count         40.000000      40.000000
# mean           5.152500   74743.625000
# std            2.663715   25947.122885
# min            1.100000   37731.000000
# 25%            3.200000   56878.250000
# 50%            4.600000   64472.500000
# 75%            6.875000   95023.250000
# max           10.500000  122391.000000

# %%
# step 3. Define target (y) & features (x)
df.columns
# Out:
# Index(['Experience Years', 'Salary'], dtype='object')

# %%
y= df['Salary']
x= df[['Experience Years']]

# %%
df.shape
# Out:
# (40, 2)

# %%
x.shape
# Out:
# (40, 1)

# %%
y.shape
# Out:
# (40,)

# %%
#step 4. Train test split

from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test= train_test_split(x,y,train_size= 0.7,random_state= 2529)
x_train
# Out:
#     Experience Years
# 28               6.5
# 31               7.9
# 34               8.7
# 20               4.7
# 4                2.0
# 3                1.5
# 18               4.3
# 26               6.0
# 2                1.3
# 22               5.1
# 35               9.0
# 7                2.9
# 39              10.5
# 30               7.1
# 10               3.2
# 0                1.1
# 9                3.2
# 13               3.8
# 5                2.2
# 37               9.6
# 23               5.3
# 25               5.9
# 21               4.9
# 24               5.5
# 8                3.0
# 36               9.5
# 15               4.0
# 32               8.2

# %%
# check shape of train and test sample
x_train.shape,x_test.shape,y_train.shape,y_test.shape
# Out:
# ((28, 1), (12, 1), (28,), (12,))

# %%
from sklearn.linear_model import LinearRegression
model= LinearRegression()

# %%
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# 26596.961311068262

# %%
model.coef_
# Out:
# array([9405.61663234])

# %%
# step 5. Select Model
from sklearn.linear_model import LinearRegression
model = LinearRegression()

# %%
# step 6. Train or Fit Model
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
# step 7. Predict model
y_pred = model.predict(x_test)
y_pred
# Out:
# array([ 90555.15441095,  59516.61952424, 106544.70268592,  64219.42784041,
#         68922.23615658, 123474.81262412,  84911.78443155,  63278.86617718,
#         65159.98950364,  61397.74285071,  37883.70126987,  50111.00289191])

# %%
# step 8. Model Accuracy
from sklearn.metrics import mean_absolute_error,mean_absolute_percentage_error,mean_squared_error
mean_absolute_error(y_test,y_pred)
# Out:
# 4005.9263101681768

# %%
mean_absolute_percentage_error(y_test,y_pred)
# Out:
# 0.06384602996141632

# %%
mean_squared_error(y_test,y_pred)
# Out:
# 24141421.671440993
